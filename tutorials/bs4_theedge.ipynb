# %%
# import libraries

import urllib
import urllib.request
import bs4 as bs4
import re
import requests
from urllib.error import HTTPError
import nltk
import numpy as np

# library NLTK

from newspaper import Article
from nltk.stem import WordNetLemmatizer
from nltk.tokenize import word_tokenize
from nltk.stem import PorterStemmer 
from nltk.tokenize import word_tokenize 

#from list_symbols import *
import pandas as pd 
import time
import json
from datetime import datetime , date

# %%
# main page the edge Malaysia

url_theedge = 'https://www.theedgemarkets.com/categories/malaysia?page=0'

# %%
# get url's html

headers = {'User-Agent' : 'Mozilla 5.10'}
request = urllib.request.Request(url_theedge, None, headers)
response = urllib.request.urlopen(request)
soup = bs4.BeautifulSoup(response,'html.parser')

# %%
link_from_mpage = soup.find_all("div", class_= "addthis_toolbox addthis_default_style addthis_32x32_style listing")

print(link_from_mpage)
links_ = []


for i in link_from_mpage:
    link_1 = i.get('addthis:url')
    links_.append(link_1)
# Out:
# [<div addthis:title="IRB says no TikTok account after viral social media claims - The Edge Markets" addthis:url="http://www.theedgemarkets.com/article/irb-says-no-tiktok-account-after-viral-social-media-claims" class="addthis_toolbox addthis_default_style addthis_32x32_style listing"><a class="addthis_button_facebook" href="#"></a>
# <a class="addthis_button_twitter" href="#"></a>
# <a class="addthis_button_whatsapp" href="#"></a>
# <a class="addthis_button_linkedin" href="#"></a>
# <a class="addthis_button_telegram" href="#"></a>
# <a class="addthis_button_email" href="#"></a>
# </div>, <div addthis:title="Police tracking Covid-19 patient who fled from Tampin Hospital - The Edge Markets" addthis:url="http://www.theedgemarkets.com/article/police-tracking-covid19-patient-who-fled-tampin-hospital" class="addthis_toolbox addthis_default_style addthis_32x32_style listing"><a class="addthis_button_facebook" href="#"></a>
# <a class="addthis_button_twitter" href="#"></a>
# <a class="addthis_button_whatsapp" href="#"></a>
# <a class="addthis_button_linkedin" href="#"></a>
# <a class="addthis_button_telegram" href="#"></a>
# <a class="addthis_button_email" href="#"></a>
# </div>, <div addthis:title="Malakoff's power-generation subsidiary proposes RM4.5b Islamic bonds - The Edge Markets" addthis:url="http://www.theedgemarkets.com/article/malakoffs-powergeneration-subsidiary-proposes-rm45b-islamic-bonds" class="addthis_toolbox addthis_default_style addthis_32x32_style listing"><a class="addthis_button_facebook" href="#"></a>
# <a class="addthis_button_twitter" href="#"></a>
# <a class="addthis_button_whatsapp" href="#"></a>
# <a class="addthis_button_linkedin" href="#"></a>
# <a class="addthis_button_telegram" href="#"></a>
# <a class="addthis_button_email" href="#"></a>
# </div>, <div addthis:title="Muafakat Nasional not exclusive to any party, says PAS sec-gen - The Edge Markets" addthis:url="http://www.theedgemarkets.com/article/muafakat-nasional-not-exclusive-any-party-says-pas-secgen" class="addthis_toolbox addthis_default_style addthis_32x32_style listing"><a class="addthis_button_facebook" href="#"></a>
# <a class="addthis_button_twitter" href="#"></a>
# <a class="addthis_button_whatsapp" href="#"></a>
# <a class="addthis_button_linkedin" href="#"></a>
# <a class="addthis_button_telegram" href="#"></a>
# <a class="addthis_button_email" href="#"></a>
# </div>, <div addthis:title="Ringgit extends gains against US dollar at opening - The Edge Markets" addthis:url="http://www.theedgemarkets.com/article/ringgit-extends-gains-against-us-dollar-opening" class="addthis_toolbox addthis_default_style addthis_32x32_style listing"><a class="addthis_button_facebook" href="#"></a>
# <a class="addthis_button_twitter" href="#"></a>
# <a class="addthis_button_whatsapp" href="#"></a>
# <a class="addthis_button_linkedin" href="#"></a>
# <a class="addthis_button_telegram" href="#"></a>
# <a class="addthis_button_email" href="#"></a>
# </div>, <div addthis:title="These are the top gainers and losers on Bursa in 2020 - The Edge Markets" addthis:url="http://www.theedgemarkets.com/article/these-are-top-gainers-and-losers-bursa-2020" class="addthis_toolbox addthis_default_style addthis_32x32_style listing"><a class="addthis_button_facebook" href="#"></a>
# <a class="addthis_button_twitter" href="#"></a>
# <a class="addthis_button_whatsapp" href="#"></a>
# <a class="addthis_button_linkedin" href="#"></a>
# <a class="addthis_button_telegram" href="#"></a>
# <a class="addthis_button_email" href="#"></a>
# </div>, <div addthis:title="KLCI opens lower on final trading day of year - The Edge Markets" addthis:url="http://www.theedgemarkets.com/article/klci-opens-lower-down-one-point-164341-902am" class="addthis_toolbox addthis_default_style addthis_32x32_style listing"><a class="addthis_button_facebook" href="#"></a>
# <a class="addthis_button_twitter" href="#"></a>
# <a class="addthis_button_whatsapp" href="#"></a>
# <a class="addthis_button_linkedin" href="#"></a>
# <a class="addthis_button_telegram" href="#"></a>
# <a class="addthis_button_email" href="#"></a>
# </div>, <div addthis:title="Sime Darby Plantation falls after US banned its palm oil products - The Edge Markets" addthis:url="http://www.theedgemarkets.com/article/sime-darby-plantation-falls-after-us-bans-cos-palm-oil-products" class="addthis_toolbox addthis_default_style addthis_32x32_style listing"><a class="addthis_button_facebook" href="#"></a>
# <a class="addthis_button_twitter" href="#"></a>
# <a class="addthis_button_whatsapp" href="#"></a>
# <a class="addthis_button_linkedin" href="#"></a>
# <a class="addthis_button_telegram" href="#"></a>
# <a class="addthis_button_email" href="#"></a>
# </div>, <div addthis:title="PTPTN records RM1.3 bil in SSPN deposits up to Nov 30 - The Edge Markets" addthis:url="http://www.theedgemarkets.com/article/ptptn-records-rm13-bil-sspn-deposits-nov-30" class="addthis_toolbox addthis_default_style addthis_32x32_style listing"><a class="addthis_button_facebook" href="#"></a>
# <a class="addthis_button_twitter" href="#"></a>
# <a class="addthis_button_whatsapp" href="#"></a>
# <a class="addthis_button_linkedin" href="#"></a>
# <a class="addthis_button_telegram" href="#"></a>
# <a class="addthis_button_email" href="#"></a>
# </div>, <div addthis:title="Penang Port Commission to offer RFP to turn ferries into tourism products - The Edge Markets" addthis:url="http://www.theedgemarkets.com/article/ppc-offer-rfp-turn-ferries-tourism-products" class="addthis_toolbox addthis_default_style addthis_32x32_style listing"><a class="addthis_button_facebook" href="#"></a>
# <a class="addthis_button_twitter" href="#"></a>
# <a class="addthis_button_whatsapp" href="#"></a>
# <a class="addthis_button_linkedin" href="#"></a>
# <a class="addthis_button_telegram" href="#"></a>
# <a class="addthis_button_email" href="#"></a>
# </div>, <div addthis:title="Air Selangor: 67% of burst pipe repair works in Damansara Utama completed - The Edge Markets" addthis:url="http://www.theedgemarkets.com/article/air-selangor-67-burst-pipe-repair-works-damansara-utama-completed" class="addthis_toolbox addthis_default_style addthis_32x32_style listing"><a class="addthis_button_facebook" href="#"></a>
# <a class="addthis_button_twitter" href="#"></a>
# <a class="addthis_button_whatsapp" href="#"></a>
# <a class="addthis_button_linkedin" href="#"></a>
# <a class="addthis_button_telegram" href="#"></a>
# <a class="addthis_button_email" href="#"></a>
# </div>, <div addthis:title="2021 the year to revive national economy via domestic tourism — Nancy - The Edge Markets" addthis:url="http://www.theedgemarkets.com/article/2021-year-revive-national-economy-domestic-tourism-%E2%80%94-nancy" class="addthis_toolbox addthis_default_style addthis_32x32_style listing"><a class="addthis_button_facebook" href="#"></a>
# <a class="addthis_button_twitter" href="#"></a>
# <a class="addthis_button_whatsapp" href="#"></a>
# <a class="addthis_button_linkedin" href="#"></a>
# <a class="addthis_button_telegram" href="#"></a>
# <a class="addthis_button_email" href="#"></a>
# </div>, <div addthis:title="Police hunt five Indonesian workers who ran away with two testing positive for Covid-19 - The Edge Markets" addthis:url="http://www.theedgemarkets.com/article/police-hunt-five-indonesian-workers-who-ran-way-two-tested-positive-covid19" class="addthis_toolbox addthis_default_style addthis_32x32_style listing"><a class="addthis_button_facebook" href="#"></a>
# <a class="addthis_button_twitter" href="#"></a>
# <a class="addthis_button_whatsapp" href="#"></a>
# <a class="addthis_button_linkedin" href="#"></a>
# <a class="addthis_button_telegram" href="#"></a>
# <a class="addthis_button_email" href="#"></a>
# </div>, <div addthis:title="Covid-19: Police roadblock at UNHCR-sanctioned settlement in Labuan - The Edge Markets" addthis:url="http://www.theedgemarkets.com/article/covid19-police-roadblock-unhcrsanctioned-settlement-labuan" class="addthis_toolbox addthis_default_style addthis_32x32_style listing"><a class="addthis_button_facebook" href="#"></a>
# <a class="addthis_button_twitter" href="#"></a>
# <a class="addthis_button_whatsapp" href="#"></a>
# <a class="addthis_button_linkedin" href="#"></a>
# <a class="addthis_button_telegram" href="#"></a>
# <a class="addthis_button_email" href="#"></a>
# </div>, <div addthis:title="Sime Darby Plantation, Tompyak, Alliance Bank, AME Elite, UEM Sunrise, Eco World, Uzma, G Capital, FGV, Stella, Willowglen and K-One - The Edge Markets" addthis:url="http://www.theedgemarkets.com/article/sime-darby-plantation-tompyak-alliance-bank-ame-elite-uem-sunrise-eco-world-uzma-g-capital" class="addthis_toolbox addthis_default_style addthis_32x32_style listing"><a class="addthis_button_facebook" href="#"></a>
# <a class="addthis_button_twitter" href="#"></a>
# <a class="addthis_button_whatsapp" href="#"></a>
# <a class="addthis_button_linkedin" href="#"></a>
# <a class="addthis_button_telegram" href="#"></a>
# <a class="addthis_button_email" href="#"></a>
# </div>]

# %%
links_
# Out:
# ['http://www.theedgemarkets.com/article/irb-says-no-tiktok-account-after-viral-social-media-claims',
#  'http://www.theedgemarkets.com/article/police-tracking-covid19-patient-who-fled-tampin-hospital',
#  'http://www.theedgemarkets.com/article/malakoffs-powergeneration-subsidiary-proposes-rm45b-islamic-bonds',
#  'http://www.theedgemarkets.com/article/muafakat-nasional-not-exclusive-any-party-says-pas-secgen',
#  'http://www.theedgemarkets.com/article/ringgit-extends-gains-against-us-dollar-opening',
#  'http://www.theedgemarkets.com/article/these-are-top-gainers-and-losers-bursa-2020',
#  'http://www.theedgemarkets.com/article/klci-opens-lower-down-one-point-164341-902am',
#  'http://www.theedgemarkets.com/article/sime-darby-plantation-falls-after-us-bans-cos-palm-oil-products',
#  'http://www.theedgemarkets.com/article/ptptn-records-rm13-bil-sspn-deposits-nov-30',
#  'http://www.theedgemarkets.com/article/ppc-offer-rfp-turn-ferries-tourism-products',
#  'http://www.theedgemarkets.com/article/air-selangor-67-burst-pipe-repair-works-damansara-utama-completed',
#  'http://www.theedgemarkets.com/article/2021-year-revive-national-economy-domestic-tourism-%E2%80%94-nancy',
#  'http://www.theedgemarkets.com/article/police-hunt-five-indonesian-workers-who-ran-way-two-tested-positive-covid19',
#  'http://www.theedgemarkets.com/article/covid19-police-roadblock-unhcrsanctioned-settlement-labuan',
#  'http://www.theedgemarkets.com/article/sime-darby-plantation-tompyak-alliance-bank-ame-elite-uem-sunrise-eco-world-uzma-g-capital']

# %%
# # three days
# today = date.today()
# print(today)
# three_days = today - timedelta(days = 4)
# print(three_days)

# %%
count = 0

condition = True

while condition :

    page = str(count)

    url_main = 'https://www.theedgemarkets.com/categories/corporate?page='+page
    print(url_main)

    count += 1

    headers = {'User-Agent' : 'Mozilla 5.10'}
    request = urllib.request.Request(url_main, None, headers)
    response = urllib.request.urlopen(request)
    soup = bs4.BeautifulSoup(response,'html.parser')

    time.sleep(2)

    links_ = soup.find_all("div", class_= "addthis_toolbox addthis_default_style addthis_32x32_style listing")

    link_main_page = []

    time.sleep(5)


    for i in links_:
        
        link_1 = i.get('addthis:url')
        link_main_page.append(link_1)


    for link in link_main_page :

        time.sleep(5)

        url_nltk = link

        article = Article(url_nltk, language="en") 
        article.download() 
        article.parse() 
        article.nlp()


        news_date_dt = article.publish_date
        print(news_date_dt)
        news_title = article.title

        # check if news date is today

        if news_date_dt.date() == date.today():

            print ("Today's news !")

            # readable date in str , iSaham format

            date_str = str(news_date_dt.strftime('%d-%b-%Y %H:%M'))

            # save title and date as dictionary

            ''' Next step insert to pymongo '''


            dict_to_pymongo = {

                "Title": news_title ,
                "Date" : news_date_dt,
                "Date str" : date_str

            }

            print(dict_to_pymongo)
        
        else:

            print("not today..")
            print(news_date_dt.date())
            condition = False

            break
# Out:
# https://www.theedgemarkets.com/categories/corporate?page=0
# lalu tak
# lalu tak
# lalu tak
# lalu tak
# lalu tak
# lalu tak
# lalu tak
# lalu tak
# lalu tak
# lalu tak
# lalu tak
# lalu tak
# lalu tak
# lalu tak
# lalu tak
# 2020-12-31 14:30:00+08:00
# Today's news !
# {'Title': 'Cover Story: Zero tolerance for corruption, and the renewable energy story', 'Date': datetime.datetime(2020, 12, 31, 14, 30, tzinfo=tzoffset(None, 28800)), 'Date str': '31-Dec-2020 14:30'}
# 2020-12-31 14:28:11+08:00
# Today's news !
# {'Title': 'Philippine islands self-isolate after new Covid-19 variant found in Malaysia', 'Date': datetime.datetime(2020, 12, 31, 14, 28, 11, tzinfo=tzoffset(None, 28800)), 'Date str': '31-Dec-2020 14:28'}
# 2020-12-31 14:15:26+08:00
# Today's news !
# {'Title': 'RSPO probes US ban on Sime Darby Plantation palm oil, confirms no red flags from earlier audit', 'Date': datetime.datetime(2020, 12, 31, 14, 15, 26, tzinfo=tzoffset(None, 28800)), 'Date str': '31-Dec-2020 14:15'}
# 2020-12-31 14:14:28+08:00
# Today's news !
# {'Title': 'US homebuyers face worst affordability squeeze in 12 years', 'Date': datetime.datetime(2020, 12, 31, 14, 14, 28, tzinfo=tzoffset(None, 28800)), 'Date str': '31-Dec-2020 14:14'}
# 2020-12-31 14:11:43+08:00
# Today's news !
# {'Title': 'Investors bullish on stocks, hoping for a brighter 2021', 'Date': datetime.datetime(2020, 12, 31, 14, 11, 43, tzinfo=tzoffset(None, 28800)), 'Date str': '31-Dec-2020 14:11'}
# 2020-12-31 14:10:06+08:00
# Today's news !
# {'Title': 'EU, China give political nod to market-opening investment pact', 'Date': datetime.datetime(2020, 12, 31, 14, 10, 6, tzinfo=tzoffset(None, 28800)), 'Date str': '31-Dec-2020 14:10'}
# 2020-12-31 14:03:59+08:00
# Today's news !
# {'Title': 'Exxon signals up to US$20b write-down to overwhelm 4Q gains in oil, chemicals', 'Date': datetime.datetime(2020, 12, 31, 14, 3, 59, tzinfo=tzoffset(None, 28800)), 'Date str': '31-Dec-2020 14:03'}
# 2020-12-31 14:00:00+08:00
# Today's news !
# {'Title': 'Cover Story: Taking over the reins at a trying time', 'Date': datetime.datetime(2020, 12, 31, 14, 0, tzinfo=tzoffset(None, 28800)), 'Date str': '31-Dec-2020 14:00'}
# 2020-12-31 13:58:20+08:00
# Today's news !
# {'Title': 'SSM to waive fee for late filing of company statutory documents from Jan 1 to 31', 'Date': datetime.datetime(2020, 12, 31, 13, 58, 20, tzinfo=tzoffset(None, 28800)), 'Date str': '31-Dec-2020 13:58'}
# 2020-12-31 13:41:28+08:00
# Today's news !
# {'Title': 'EPF announces temporary closure of Kota Kinabalu branch', 'Date': datetime.datetime(2020, 12, 31, 13, 41, 28, tzinfo=tzoffset(None, 28800)), 'Date str': '31-Dec-2020 13:41'}
# 2020-12-31 13:34:17+08:00
# Today's news !
# {'Title': 'Bursa Malaysia ends morning session lower', 'Date': datetime.datetime(2020, 12, 31, 13, 34, 17, tzinfo=tzoffset(None, 28800)), 'Date str': '31-Dec-2020 13:34'}
# 2020-12-31 13:32:57+08:00
# Today's news !
# {'Title': 'Petronas says O&G sector outlook challenging on Covid-19, OPEC+ production cut uncertainties', 'Date': datetime.datetime(2020, 12, 31, 13, 32, 57, tzinfo=tzoffset(None, 28800)), 'Date str': '31-Dec-2020 13:32'}
# 2020-12-31 13:21:13+08:00
# Today's news !
# {'Title': 'UK-Singapore free trade agreement to begin Jan 1', 'Date': datetime.datetime(2020, 12, 31, 13, 21, 13, tzinfo=tzoffset(None, 28800)), 'Date str': '31-Dec-2020 13:21'}
# 2020-12-31 13:14:00+08:00
# Today's news !
# {'Title': 'China gives its first Covid-19 vaccine approval to Sinopharm', 'Date': datetime.datetime(2020, 12, 31, 13, 14, tzinfo=tzoffset(None, 28800)), 'Date str': '31-Dec-2020 13:14'}
# 2020-12-31 13:13:08+08:00
# Today's news !
# {'Title': 'Vaccines, stimulus set tone for 2021 as year ends on bullish note', 'Date': datetime.datetime(2020, 12, 31, 13, 13, 8, tzinfo=tzoffset(None, 28800)), 'Date str': '31-Dec-2020 13:13'}
# https://www.theedgemarkets.com/categories/corporate?page=1
# lalu tak
# lalu tak
# lalu tak
# lalu tak
# lalu tak
# lalu tak
# lalu tak
# lalu tak
# lalu tak
# lalu tak
# lalu tak
# lalu tak
# lalu tak
# lalu tak
# lalu tak
# 2020-12-31 12:58:08+08:00
# Today's news !
# {'Title': "A divided UK exits EU's orbit, enters Brexit unknown", 'Date': datetime.datetime(2020, 12, 31, 12, 58, 8, tzinfo=tzoffset(None, 28800)), 'Date str': '31-Dec-2020 12:58'}
# 2020-12-31 12:24:35+08:00
# Today's news !
# {'Title': 'Chinese yuan, stocks climb to new highs in bullish end to year', 'Date': datetime.datetime(2020, 12, 31, 12, 24, 35, tzinfo=tzoffset(None, 28800)), 'Date str': '31-Dec-2020 12:24'}
# 2020-12-31 12:21:46+08:00
# Today's news !
# {'Title': 'Socso has bought almost one million Covid-19 RTK-antigen test kits for screening foreign workers in six states', 'Date': datetime.datetime(2020, 12, 31, 12, 21, 46, tzinfo=tzoffset(None, 28800)), 'Date str': '31-Dec-2020 12:21'}
# 2020-12-31 12:19:59+08:00
# Today's news !
# {'Title': 'US slaps tariffs on French and German wines, aircraft parts amid EU dispute', 'Date': datetime.datetime(2020, 12, 31, 12, 19, 59, tzinfo=tzoffset(None, 28800)), 'Date str': '31-Dec-2020 12:19'}
# 2020-12-31 12:13:37+08:00
# Today's news !
# {'Title': 'Temperature snag delayed 144,000 Moderna shots bound for Texas', 'Date': datetime.datetime(2020, 12, 31, 12, 13, 37, tzinfo=tzoffset(None, 28800)), 'Date str': '31-Dec-2020 12:13'}
# 2020-12-31 12:09:56+08:00
# Today's news !
# {'Title': 'Bitcoin touches US$29,000 for another high in banner year', 'Date': datetime.datetime(2020, 12, 31, 12, 9, 56, tzinfo=tzoffset(None, 28800)), 'Date str': '31-Dec-2020 12:09'}
# 2020-12-31 12:09:55+08:00
# Today's news !
# {'Title': 'Move over Mukesh Ambani, Asia has a new richest person', 'Date': datetime.datetime(2020, 12, 31, 12, 9, 55, tzinfo=tzoffset(None, 28800)), 'Date str': '31-Dec-2020 12:09'}
# 2020-12-31 12:03:50+08:00
# Today's news !
# {'Title': 'China is making it harder to solve the mystery of how Covid-19 began', 'Date': datetime.datetime(2020, 12, 31, 12, 3, 50, tzinfo=tzoffset(None, 28800)), 'Date str': '31-Dec-2020 12:03'}
# 2020-12-31 11:59:43+08:00
# Today's news !
# {'Title': 'Bank of Korea to maintain easy policy until stable recovery seen in 2021', 'Date': datetime.datetime(2020, 12, 31, 11, 59, 43, tzinfo=tzoffset(None, 28800)), 'Date str': '31-Dec-2020 11:59'}
# 2020-12-31 11:58:45+08:00
# Today's news !
# {'Title': "China's services activity growth slows in December — official PMI", 'Date': datetime.datetime(2020, 12, 31, 11, 58, 45, tzinfo=tzoffset(None, 28800)), 'Date str': '31-Dec-2020 11:58'}
# 2020-12-31 11:44:49+08:00
# Today's news !
# {'Title': 'London’s luxury new home slump stings Asian developers', 'Date': datetime.datetime(2020, 12, 31, 11, 44, 49, tzinfo=tzoffset(None, 28800)), 'Date str': '31-Dec-2020 11:44'}
# 2020-12-31 11:39:39+08:00
# Today's news !
# {'Title': 'Oil set for 20% drop in 2020 as lockdowns weigh, market eyes more stimulus', 'Date': datetime.datetime(2020, 12, 31, 11, 39, 39, tzinfo=tzoffset(None, 28800)), 'Date str': '31-Dec-2020 11:39'}
# 2020-12-31 11:32:53+08:00
# Today's news !
# {'Title': 'Dollar sucked into downward spiral by US twin deficits', 'Date': datetime.datetime(2020, 12, 31, 11, 32, 53, tzinfo=tzoffset(None, 28800)), 'Date str': '31-Dec-2020 11:32'}
# 2020-12-31 11:26:59+08:00
# Today's news !
# {'Title': "China's factory recovery moderates as higher costs slow business", 'Date': datetime.datetime(2020, 12, 31, 11, 26, 59, tzinfo=tzoffset(None, 28800)), 'Date str': '31-Dec-2020 11:26'}
# 2020-12-31 11:03:49+08:00
# Today's news !
# {'Title': "Singapore's 2021 budget to be announced on Feb 16", 'Date': datetime.datetime(2020, 12, 31, 11, 3, 49, tzinfo=tzoffset(None, 28800)), 'Date str': '31-Dec-2020 11:03'}
# https://www.theedgemarkets.com/categories/corporate?page=2
# lalu tak
# lalu tak
# lalu tak
# lalu tak
# lalu tak
# lalu tak
# lalu tak
# lalu tak
# lalu tak
# lalu tak
# lalu tak
# lalu tak
# lalu tak
# lalu tak
# lalu tak
# 2020-12-31 11:26:59+08:00
# Today's news !
# {'Title': "China's factory recovery moderates as higher costs slow business", 'Date': datetime.datetime(2020, 12, 31, 11, 26, 59, tzinfo=tzoffset(None, 28800)), 'Date str': '31-Dec-2020 11:26'}
# 2020-12-31 11:03:49+08:00
# Today's news !
# {'Title': "Singapore's 2021 budget to be announced on Feb 16", 'Date': datetime.datetime(2020, 12, 31, 11, 3, 49, tzinfo=tzoffset(None, 28800)), 'Date str': '31-Dec-2020 11:03'}
# 2020-12-31 10:51:34+08:00
# Today's news !
# {'Title': "Malakoff's power-generation subsidiary proposes RM4.5b Islamic bonds", 'Date': datetime.datetime(2020, 12, 31, 10, 51, 34, tzinfo=tzoffset(None, 28800)), 'Date str': '31-Dec-2020 10:51'}
# 2020-12-31 10:36:48+08:00
# Today's news !
# {'Title': 'UK Parliament approves Brexit trade deal with EU as both sides look to future', 'Date': datetime.datetime(2020, 12, 31, 10, 36, 48, tzinfo=tzoffset(None, 28800)), 'Date str': '31-Dec-2020 10:36'}
# 2020-12-31 10:24:35+08:00
# Today's news !
# {'Title': 'Ringgit extends gains against US dollar at opening', 'Date': datetime.datetime(2020, 12, 31, 10, 24, 35, tzinfo=tzoffset(None, 28800)), 'Date str': '31-Dec-2020 10:24'}
# 2020-12-31 10:00:00+08:00
# Today's news !
# {'Title': 'These are the top gainers and losers on Bursa in 2020', 'Date': datetime.datetime(2020, 12, 31, 10, 0, tzinfo=tzoffset(None, 28800)), 'Date str': '31-Dec-2020 10:00'}
# 2020-12-31 09:46:00+08:00
# Today's news !
# {'Title': 'KLCI opens lower on final trading day of year', 'Date': datetime.datetime(2020, 12, 31, 9, 46, tzinfo=tzoffset(None, 28800)), 'Date str': '31-Dec-2020 09:46'}
# 2020-12-31 09:07:30+08:00
# Today's news !
# {'Title': 'Sime Darby Plantation falls after US banned its palm oil products', 'Date': datetime.datetime(2020, 12, 31, 9, 7, 30, tzinfo=tzoffset(None, 28800)), 'Date str': '31-Dec-2020 09:07'}
# 2020-12-31 08:44:51+08:00
# Today's news !
# {'Title': 'Asian shares hover near record high; risk currencies in favour', 'Date': datetime.datetime(2020, 12, 31, 8, 44, 51, tzinfo=tzoffset(None, 28800)), 'Date str': '31-Dec-2020 08:44'}
# 2020-12-31 08:00:12+08:00
# Today's news !
# {'Title': 'Oil prices rise as US crude stock draw supports but demand hopes dim', 'Date': datetime.datetime(2020, 12, 31, 8, 0, 12, tzinfo=tzoffset(None, 28800)), 'Date str': '31-Dec-2020 08:00'}
# 2020-12-31 07:55:38+08:00
# Today's news !
# {'Title': 'Wall St ends higher on recovery expectations', 'Date': datetime.datetime(2020, 12, 31, 7, 55, 38, tzinfo=tzoffset(None, 28800)), 'Date str': '31-Dec-2020 07:55'}
# 2020-12-31 02:21:03+08:00
# Today's news !
# {'Title': 'Wall Street rises on hopes of vaccine-fueled recovery', 'Date': datetime.datetime(2020, 12, 31, 2, 21, 3, tzinfo=tzoffset(None, 28800)), 'Date str': '31-Dec-2020 02:21'}
# 2020-12-31 01:38:16+08:00
# Today's news !
# {'Title': 'Penang Port Commission to offer RFP to turn ferries into tourism products', 'Date': datetime.datetime(2020, 12, 31, 1, 38, 16, tzinfo=tzoffset(None, 28800)), 'Date str': '31-Dec-2020 01:38'}
# 2020-12-31 01:33:52+08:00
# Today's news !
# {'Title': 'Air Selangor: 67% of burst pipe repair works in Damansara Utama completed', 'Date': datetime.datetime(2020, 12, 31, 1, 33, 52, tzinfo=tzoffset(None, 28800)), 'Date str': '31-Dec-2020 01:33'}
# 2020-12-31 01:12:10+08:00
# Today's news !
# {'Title': 'Sime Darby Plantation, Tompyak, Alliance Bank, AME Elite, UEM Sunrise, Eco World, Uzma, G Capital, FGV, Stella, Willowglen and K-One', 'Date': datetime.datetime(2020, 12, 31, 1, 12, 10, tzinfo=tzoffset(None, 28800)), 'Date str': '31-Dec-2020 01:12'}
# https://www.theedgemarkets.com/categories/corporate?page=3
# lalu tak
# lalu tak
# lalu tak
# lalu tak
# lalu tak
# lalu tak
# lalu tak
# lalu tak
# lalu tak
# lalu tak
# lalu tak
# lalu tak
# lalu tak
# lalu tak
# lalu tak
# 2020-12-30 23:21:18+08:00
# not today..
# 2020-12-30
